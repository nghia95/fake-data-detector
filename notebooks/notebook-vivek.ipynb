# %%
import os
print(os.getcwd())
# Out:
# /home/vivek/code/nghia95/fake-data-detector/notebooks

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the updated file path
file_path = '/home/vivek/code/nghia95/fake-data-detector/data/1k_sampled_dataset.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
print(df.head())
# Out:
#                                                 text       source  prompt_id  \
# 0  The Philosophy and Ethics of Transhumanism\n\n...      GPT-3.5       1920
# 1  Crime-tracking app Citizen is launching its ow...  Flan-T5-XXL          0
# 2  The court in Novorossiysk gave two of the danc...     GLM-130B          0
# 3  then drops the drumsticks, poses, then walks o...        GPT-J          0
# 4  On tally went to the beach. She found a sand d...        GPT-J          0
#
#    text_length  word_count
# 0         2558         394
# 1          378          62
# 2          621         109
# 3          513          90
# 4         4984         846

# %%
# Get a summary of the dataset
print(df.info())

# Check for missing values
print(df.isnull().sum())

# Statistical summary for numerical columns
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         1000 non-null   object
#  1   source       1000 non-null   object
#  2   prompt_id    1000 non-null   int64
#  3   text_length  1000 non-null   int64
#  4   word_count   1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB
# None
# text           0
# source         0
# prompt_id      0
# text_length    0
# word_count     0
# dtype: int64
#          prompt_id    text_length    word_count
# count  1000.000000    1000.000000   1000.000000
# mean    300.128000    4778.830000    749.872000
# std    1084.888097    7749.495296   1124.777569
# min       0.000000     128.000000     25.000000
# 25%       0.000000     937.500000    162.000000
# 50%       0.000000    3277.500000    542.500000
# 75%       0.000000    5220.000000    844.500000
# max    9209.000000  120734.000000  15441.000000

# %%
df.hist(figsize=(10, 8))
plt.show()
